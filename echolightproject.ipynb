# %%
import IPython.display as ipd
import os
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation

import requests
import json

def pushbullet_noti(title, body):

    TOKEN = 'o.wWIKfxozypLiqKYF9xMskSubtPynLO0D' # Pass your Access Token here
    # Make a dictionary that includes, title and body
    msg = {"type": "note", "title": title, "body": body}
    # Sent a posts request
    resp = requests.post('https://api.pushbullet.com/v2/pushes',
                        data=json.dumps(msg),
                        headers={'Authorization': 'Bearer ' + TOKEN,
                                'Content-Type': 'application/json'})
    if resp.status_code != 200: # Check if fort message send with the help of status code
        raise Exception('Error', resp.status_code)
    else:
        print('Message sent')

# %%
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv('/content/drive/MyDrive/MajorProject/audio33.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install gtts
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gtts) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.11/dist-packages (from gtts) (8.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (2025.1.31)

# %%
mfc=[]
chr=[]
me=[]
ton=[]
lab=[]
for i in tqdm(range(len(data))):
  f_name='/content/drive/MyDrive/MajorProject/audio/soundd/'+str(data.filename[i])
  X, s_rate = librosa.load(f_name)
  mf = np.mean(librosa.feature.mfcc(y=X, sr=s_rate).T,axis=0)
  mfc.append(mf)
  l = data.category[i]
  lab.append(l)
  m = np.mean(librosa.feature.melspectrogram(y=X,sr=s_rate).T,axis=0)
  me.append(m)
  s = np.abs(librosa.stft(X))
  c = np.mean(librosa.feature.chroma_stft(S=s,sr=s_rate).T,axis=0)
  chr.append(c)
  try:
    t = np.mean(librosa.feature.tonnetz(y = librosa.effects.harmonic(X),sr=s_rate).T,axis=0)
    ton.append(t)
  except:
    print(f_name)
# Out:
# 100%|██████████| 76/76 [00:52<00:00,  1.46it/s]

# %%
mfcc = pd.DataFrame(mfc)
mfcc.to_csv('/content/drive/MyDrive/MajorProject/Features/mfc.csv',index = False)
chrr = pd.DataFrame(chr)
chrr.to_csv('/content/drive/MyDrive/MajorProject/Features/chr.csv',index = False)
mee = pd.DataFrame(me)
mee.to_csv('/content/drive/MyDrive/MajorProject/Features/me.csv',index = False)
tonn = pd.DataFrame(ton)
tonn.to_csv('/content/drive/MyDrive/MajorProject/Features/ton.csv',index = False)
la = pd.DataFrame(lab)
la.to_csv('/content/drive/MyDrive/MajorProject/Features/labels.csv',index = False)

# %%
features=[]
for i in range(len(ton)):
  features.append(np.concatenate((me[i],mfc[i],ton[i],chr[i]),axis = 0))

la = pd.get_dummies(lab)
label_columns = la.columns
target = la.to_numpy()
print(label_columns)

tran = StandardScaler()
features_train = tran.fit_transform(mfc)

feat_train = features_train[:60]
target_train = target[:60]
y_train = features_train[60:68]
y_val = target[60:68]
test_data = features_train[68:]
test_label = lab[68:]

print("Training",feat_train.shape)
print(target_train.shape)
print("Validation",y_train.shape)
print(y_val.shape)
print("Test",test_data.shape)

model = Sequential()
model.add(Dense(186, input_shape=(20,), activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.6))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

history = model.fit(feat_train, target_train, batch_size=25, epochs=100, validation_data=(y_train, y_val))

train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10,7))
plt.plot(train_acc,label='Training Accuracy',color='blue')
plt.plot(val_acc,label='Validation Accuracy',color = 'yellow')
plt.title('Training and Validation Accuracy',fontsize=21)
plt.xlabel('Epoch',fontsize=15)
plt.legend(fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
plt.xticks(range(0,30,5),range(0,30,5))

predict = model.predict(test_data)
predict = np.argmax(predict,axis=1)
predict

prediction=[]
for i in predict:
  j = label_columns[i]
  prediction.append(j)
prediction

k = 0
for i,j in zip(test_label,prediction):
  if(i==j):
    k+=1
print(k)
print(test_label)
print(prediction)
# Out:
# Index(['chirping_birds', 'clapping', 'clock_alarm', 'crow', 'dog',
#        'door_wood_knock', 'footsteps'],
#       dtype='object')
# Training (60, 20)
# (60, 7)
# Validation (8, 20)
# (8, 7)
# Test (8, 20)
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - accuracy: 0.1117 - loss: 2.1104 - val_accuracy: 0.1250 - val_loss: 1.8403
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2883 - loss: 1.9712 - val_accuracy: 0.1250 - val_loss: 1.7812
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2950 - loss: 1.7800 - val_accuracy: 0.1250 - val_loss: 1.7264
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3600 - loss: 1.7771 - val_accuracy: 0.1250 - val_loss: 1.6763
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3233 - loss: 1.6840 - val_accuracy: 0.2500 - val_loss: 1.6335
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3367 - loss: 1.5769 - val_accuracy: 0.2500 - val_loss: 1.5787
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4517 - loss: 1.4710 - val_accuracy: 0.2500 - val_loss: 1.5241
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5083 - loss: 1.3960 - val_accuracy: 0.3750 - val_loss: 1.4747
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5567 - loss: 1.3890 - val_accuracy: 0.3750 - val_loss: 1.4283
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5300 - loss: 1.2861 - val_accuracy: 0.5000 - val_loss: 1.3770
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5650 - loss: 1.2087 - val_accuracy: 0.5000 - val_loss: 1.3330
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5017 - loss: 1.2265 - val_accuracy: 0.5000 - val_loss: 1.3054
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6567 - loss: 1.1246 - val_accuracy: 0.5000 - val_loss: 1.2762
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5767 - loss: 1.1579 - val_accuracy: 0.6250 - val_loss: 1.2464
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7767 - loss: 0.9429 - val_accuracy: 0.6250 - val_loss: 1.2015
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7000 - loss: 0.9244 - val_accuracy: 0.6250 - val_loss: 1.1613
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6600 - loss: 0.8688 - val_accuracy: 0.6250 - val_loss: 1.1327
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7367 - loss: 0.7953 - val_accuracy: 0.6250 - val_loss: 1.0996
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7600 - loss: 0.8487 - val_accuracy: 0.6250 - val_loss: 1.0687
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8350 - loss: 0.7068 - val_accuracy: 0.5000 - val_loss: 1.0415
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7667 - loss: 0.7200 - val_accuracy: 0.5000 - val_loss: 1.0301
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8233 - loss: 0.7133 - val_accuracy: 0.5000 - val_loss: 1.0236
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7267 - loss: 0.6433 - val_accuracy: 0.6250 - val_loss: 1.0099
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8050 - loss: 0.6472 - val_accuracy: 0.5000 - val_loss: 1.0000
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9333 - loss: 0.4648 - val_accuracy: 0.5000 - val_loss: 0.9927
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8450 - loss: 0.5164 - val_accuracy: 0.5000 - val_loss: 0.9914
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8183 - loss: 0.5822 - val_accuracy: 0.5000 - val_loss: 0.9955
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8367 - loss: 0.5212 - val_accuracy: 0.5000 - val_loss: 1.0152
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8650 - loss: 0.5151 - val_accuracy: 0.5000 - val_loss: 1.0487
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9767 - loss: 0.0806 - val_accuracy: 0.6250 - val_loss: 1.4340
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9783 - loss: 0.0694 - val_accuracy: 0.6250 - val_loss: 1.4409
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0942 - val_accuracy: 0.6250 - val_loss: 1.4408
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0759 - val_accuracy: 0.6250 - val_loss: 1.4442
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0803 - val_accuracy: 0.6250 - val_loss: 1.4417
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9767 - loss: 0.1038 - val_accuracy: 0.6250 - val_loss: 1.4323
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9917 - loss: 0.0742 - val_accuracy: 0.6250 - val_loss: 1.4234
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9767 - loss: 0.0876 - val_accuracy: 0.6250 - val_loss: 1.4225
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0635 - val_accuracy: 0.6250 - val_loss: 1.4346
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0505 - val_accuracy: 0.6250 - val_loss: 1.4400
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9917 - loss: 0.0552 - val_accuracy: 0.6250 - val_loss: 1.4402
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.6250 - val_loss: 1.4389
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0322 - val_accuracy: 0.6250 - val_loss: 1.4406
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9917 - loss: 0.0465 - val_accuracy: 0.6250 - val_loss: 1.4496
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9867 - loss: 0.0670 - val_accuracy: 0.6250 - val_loss: 1.4677
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9633 - loss: 0.0556 - val_accuracy: 0.6250 - val_loss: 1.4686
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.6250 - val_loss: 1.4654
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9867 - loss: 0.0501 - val_accuracy: 0.6250 - val_loss: 1.4590
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9867 - loss: 0.0509 - val_accuracy: 0.6250 - val_loss: 1.4386
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.6250 - val_loss: 1.4242
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0418 - val_accuracy: 0.6250 - val_loss: 1.4194
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9867 - loss: 0.0600 - val_accuracy: 0.6250 - val_loss: 1.4224
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0315 - val_accuracy: 0.6250 - val_loss: 1.4207
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.6250 - val_loss: 1.4157
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.6250 - val_loss: 1.4173
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.6250 - val_loss: 1.4221
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.6250 - val_loss: 1.4275
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9733 - loss: 0.0708 - val_accuracy: 0.6250 - val_loss: 1.4243
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 0.6250 - val_loss: 1.3527
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 0.6250 - val_loss: 1.3097
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9867 - loss: 0.0305 - val_accuracy: 0.6250 - val_loss: 1.3034
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.6250 - val_loss: 1.3032
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.6250 - val_loss: 1.3058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1
# ['chirping_birds', 'footsteps', 'footsteps', 'footsteps', 'footsteps', 'footsteps', 'footsteps', 'footsteps']
# ['chirping_birds', 'door_wood_knock', 'door_wood_knock', 'door_wood_knock', 'door_wood_knock', 'door_wood_knock', 'door_wood_knock', 'door_wood_knock']

# %%
# all imports
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=5):
    print("Speak now")
    display(Javascript(RECORD))
    s = output.eval_js(f'record({sec * 1000})')
    b = b64decode(s.split(',')[1])
    with open('audio.wav', 'wb') as f:
        f.write(b)
    print("Done Recording")
    return 'audio.wav'

record()
# Out:
# Speak now
# Done Recording
# 'audio.wav'

# %%
ipd.Audio("/content/audio.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def pushbullet_noti(title, body):

    TOKEN = 'o.kQ0xOXvuStQxWv5uVComeqnoYRqRaWWH' # Pass your Access Token here
    # Make a dictionary that includes, title and body
    msg = {"type": "note", "title": title, "body": body}
    # Sent a posts request
    resp = requests.post('https://api.pushbullet.com/v2/pushes',
                        data=json.dumps(msg),
                        headers={'Authorization': 'Bearer ' + TOKEN,
                                'Content-Type': 'application/json'})
    if resp.status_code != 200: # Check if fort message send with the help of status code
        raise Exception('Error', resp.status_code)
    else:
        print('Message sent')

# %%
f_nname='/content/audio.wav'
Xx, ss_rate = librosa.load(f_nname)
mff = np.mean(librosa.feature.mfcc(y=Xx, sr=ss_rate).T,axis=0)
src=tran.transform(mff.reshape(1,-1))
#print(src)

i = np.argmax(model.predict(src), axis=-1)
print("Predicted Value is",label_columns[i])
#print(model.predict(src),label_columns)

from gtts import gTTS
from IPython.display import Audio
if(i==0):
  tts = gTTS('Alexa,change the colour of the bulb to Green',tld='co.in')
  print('Predicted Sound is Chirping Birds Sound')
  pushbullet_noti("Sound", "Chirping Birds Sound")
  tts.save('AudioOut.wav')
if(i==1):
   tts = gTTS('Alexa,change the colour of the bulb to Pink',tld='co.in')
   pushbullet_noti("Sound", "Clapping")
   print('Predicted Sound is Clapping')
   tts.save('AudioOut.wav')
if(i==2):
   tts = gTTS('Alexa,change the colour of the bulb to Yellow',tld='co.in')
   pushbullet_noti("Sound", "Alaram Sound")
   print('Predicted Sound is Alaram Sound')
   tts.save('AudioOut.wav')
if(i==3):
   tts = gTTS('Alexa,change the colour of the bulb to Gold',tld='co.in')
   pushbullet_noti("Sound", "Crow sound")
   print('Predicted Sound is Crow sound')
   tts.save('AudioOut.wav')
if(i==4):
   tts = gTTS('Alexa,change the colour of the bulb to Red',tld='co.in')
   pushbullet_noti("Sound", "Dog Barking")
   print('Predicted Sound is Dog Barking')
   tts.save('AudioOut.wav')
if(i==5):
   tts = gTTS('Alexa,change the colour of the bulb to Blue',tld='co.in')
   pushbullet_noti("Sound", "Door Wood Knock")
   print('Predicted Sound is Door Wood Knock')
   tts.save('AudioOut.wav')
if(i==6):
   tts = gTTS('Alexa,change the colour of the bulb to Cyan',tld='co.in')
   pushbullet_noti("Sound", "Foot Steps")
   print('Predicted Sound is Foot Steps')
   tts.save('AudioOut.wav')
Audio('AudioOut.wav',autoplay=True)
# Out:
# <ipython-input-43-05f005b16171>:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   Xx, ss_rate = librosa.load(f_nname)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7903b4759580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Predicted Value is Index(['door_wood_knock'], dtype='object')
# Message sent
# Predicted Sound is Door Wood Knock
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
